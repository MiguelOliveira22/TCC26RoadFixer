# %%
# !pip install pandas geopandas torch fastapi[standard] joblib matplotlib seaborn
# Out:
# ...
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    ---------------------------------------- 9.5/9.5 MB 89.4 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 2.5/2.5 MB 86.2 MB/s  0:00:00
# ...
#
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
# ...

# %%
import torch
import pandas
from sklearn.cluster import DBSCAN
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.metrics import silhouette_samples
from sklearn.preprocessing import StandardScaler

import joblib

# %%
main = Pipeline([("Scale", StandardScaler()), ("Clusterize", DBSCAN())])
toim = GridSearchCV(main, n_jobs=-1)

toim.best_estimator_.

joblib.dump(main.named_steps["Clusterize"], "a.pkl")

# %%
tome = joblib.load("a.pkl")
