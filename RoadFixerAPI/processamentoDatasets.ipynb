# %%
# !pip install pandas matplotlib seaborn

# %%
import pandas
import seaborn
import re

from matplotlib import pyplot
from pathlib import Path

# %% [markdown]
# CONSTANTS - Acidentes

# %%
YEAR = 2026
PATHACIDENTES = Path("Datasets", "accidents", "nonProcessed")

# %%
datasetAcidentes = pandas.read_csv(Path(PATHACIDENTES, f"{YEAR}.csv"))

# %%
datasetAcidentes = datasetAcidentes.loc[datasetAcidentes.RODOVIA.str.contains("330")]
# Out:
#              DATA      HORA   CONCESSIONARIA     RODOVIA     KM SENTIDO  \
# 0      2026-01-01  05:13:08      L01-AUTOBAN       SP330   72.9   NORTE
# 3      2026-01-01  22:04:16      L01-AUTOBAN       SP330   63.0     SUL
# 5      2026-01-02  12:08:46      L01-AUTOBAN       SP330   13.5   NORTE
# 7      2026-01-02  18:40:39      L01-AUTOBAN       SP330  121.0     SUL
# 8      2026-01-03  06:08:10      L01-AUTOBAN       SP330   91.1   NORTE
# ...           ...       ...              ...         ...    ...     ...
# 26986  2026-08-03  19:12:23  L29-VIAPAULISTA  SPD307/330  307.5   NORTE
# 26987  2026-08-04  08:14:00  L29-VIAPAULISTA  SPD305/330  305.7     SUL
# 26988  2026-08-06  12:38:41  L29-VIAPAULISTA  SPD307/330  307.5     SUL
# 26990  2026-08-07  05:30:10  L29-VIAPAULISTA  SPD307/330  307.5   NORTE
# 26991  2026-08-07  06:59:59  L29-VIAPAULISTA  SPD307/330  307.5   NORTE
#
#         LATITUDE  LONGITUDE         CLASSE                SUBCLASSE  ...  \
# ...

# %% [markdown]
# CONSTANTS - Volume Trafego

# %%
A

# %% [markdown]
# CONSTANTS - Clima

# %% [markdown]
# CONSTANTS - Infraestrutura
